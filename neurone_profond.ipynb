# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank_neurone=pd.read_csv('bank.csv')
bank_neurone.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
# information sur la base de données

bank_neurone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
for i in bank_neurone.select_dtypes(include='object').columns:
    print(i, bank_neurone[i].nunique())
# Out:
# job 12
# marital 3
# education 4
# default 2
# housing 2
# loan 2
# contact 3
# month 12
# poutcome 4
# deposit 2

# %%
# affichage des valeur uniques des variable objects

for i in bank_neurone.select_dtypes(include='object').columns:
    bank_neurone[i].value_counts().plot(kind='bar')
    plt.show()

# %%
for i in bank_neurone.select_dtypes(include='int').columns:
    sns.distplot(bank_neurone[i])
    plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9912\4274819969.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bank_neurone[i])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9912\4274819969.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bank_neurone[i])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9912\4274819969.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bank_neurone[i])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9912\4274819969.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bank_neurone[i])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9912\4274819969.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bank_neurone[i])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9912\4274819969.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bank_neurone[i])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9912\4274819969.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bank_neurone[i])

# %%
bank_neurone.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# max      854.000000     58.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %%
bank_neurone.shape
# Out:
# (11162, 17)

# %%
"""np_bank=bank_neurone.to_numpy()
np_bank[ : 5, ]"""
# Out:
# 'np_bank=bank_neurone.to_numpy()\nnp_bank[ : 5, ]'

# %%
# Select features and labels
"""features = np_bank[ : , :16]
labels = np_bank[ : , -1: ] 
labels[ : 5, ]"""
# Out:
# 'features = np_bank[ : , :16]\nlabels = np_bank[ : , -1: ] \nlabels[ : 5, ]'

# %%
features=bank_neurone.drop(['deposit'], axis=1)
labels=bank_neurone['deposit']

# %%
for i in features.select_dtypes(include='object').columns:
    features[i]=features[i].astype('category').cat.codes

# %%
features.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome
# 0    5      8      1042         1     -1         0         3
# 1    5      8      1467         1     -1         0         3
# 2    5      8      1389         1     -1         0         3
# 3    5      8       579         1     -1         0         3
# 4    5      8       673         2     -1         0         3

# %%
feature_np=features.to_numpy()
labels_np=labels.to_numpy()
feature_np.shape
labels_np.shape
# Out:
# (11162,)

# %%
labels_np=labels_np.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features_scaler = scaler.fit_transform(feature_np)

features_scaler
# Out:
# array([[ 1.49150488, -1.39160402, -0.31867191, ..., -0.48118405,
#         -0.36325984,  0.52070456],
#        [ 1.23967567, -1.39160402, -0.31867191, ..., -0.48118405,
#         -0.36325984,  0.52070456],
#        [-0.0194704 ,  1.39910458, -0.31867191, ..., -0.48118405,
#         -0.36325984,  0.52070456],
#        ...,
#        [-0.77495804,  1.39910458,  1.27998692, ..., -0.48118405,
#         -0.36325984,  0.52070456],
#        [ 0.14841574,  1.39910458, -0.31867191, ...,  1.10957066,
#          1.81833188, -2.47059976],
#        [-0.6070719 ,  1.39910458, -0.31867191, ..., -0.48118405,
#         -0.36325984,  0.52070456]], shape=(11162, 16))

# %%
encoder = OneHotEncoder(sparse_output=False)
encoded_labels = encoder.fit_transform(labels_np)
encoded_labels
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]], shape=(11162, 2))

# %%
# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features_scaler, 
                encoded_labels, test_size=0.2, random_state=42)

# %%
# Build the model
model = Sequential([
    # First hidden layer: 2 neurons with 'relu' activation for non-linear patterns
    Dense(units=10, activation='relu', input_dim=16),
    # Additional hidden layers: increasing capacity to learn complex representations
    Dense(units=16, activation='relu'),
    Dense(units=16, activation='relu'),
    Dense(units=16, activation='relu'),
    Dense(units=16, activation='relu'),
    Dense(units=16, activation='relu'),
    Dense(units=16, activation='relu'),
    # Output layer: 1 neuron with 'softmax' activation to output a probability
    Dense(units=2, activation='softmax')])
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, 
loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                │ (None, 10)             │           170 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 16)             │           176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,740 (6.80 KB)
#  Trainable params: 1,740 (6.80 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(x_train, y_train, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7174 - loss: 0.5439
# Epoch 2/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7945 - loss: 0.4569
# Epoch 3/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8068 - loss: 0.4400
# Epoch 4/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8106 - loss: 0.4306
# Epoch 5/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8139 - loss: 0.4230
# Epoch 6/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8169 - loss: 0.4181
# Epoch 7/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8195 - loss: 0.4143
# Epoch 8/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8202 - loss: 0.4118
# Epoch 9/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8210 - loss: 0.4085
# Epoch 10/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8208 - loss: 0.4074
# Epoch 11/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8226 - loss: 0.4058
# Epoch 12/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8237 - loss: 0.4051
# Epoch 13/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8239 - loss: 0.4025
# Epoch 14/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8257 - loss: 0.4025
# Epoch 15/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8260 - loss: 0.4005
# Epoch 16/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8233 - loss: 0.4006
# Epoch 17/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8280 - loss: 0.3980
# Epoch 18/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8270 - loss: 0.3959
# Epoch 19/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8270 - loss: 0.3967
# Epoch 20/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8281 - loss: 0.3951
# Epoch 21/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8281 - loss: 0.3926
# Epoch 22/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8274 - loss: 0.3918
# Epoch 23/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8286 - loss: 0.3908
# Epoch 24/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8290 - loss: 0.3912
# Epoch 25/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8284 - loss: 0.3892
# Epoch 26/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8281 - loss: 0.3887
# Epoch 27/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8290 - loss: 0.3874
# Epoch 28/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8321 - loss: 0.3861
# Epoch 29/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8290 - loss: 0.3869
# Epoch 30/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8281 - loss: 0.3853
# Epoch 31/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8320 - loss: 0.3830
# Epoch 32/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8334 - loss: 0.3821
# Epoch 33/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8295 - loss: 0.3821
# Epoch 34/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8317 - loss: 0.3810
# Epoch 35/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8314 - loss: 0.3814
# Epoch 36/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8335 - loss: 0.3794
# Epoch 37/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8342 - loss: 0.3783
# Epoch 38/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8312 - loss: 0.3787
# Epoch 39/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8341 - loss: 0.3764
# Epoch 40/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8320 - loss: 0.3774
# Epoch 41/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8325 - loss: 0.3762
# Epoch 42/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8317 - loss: 0.3754
# Epoch 43/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8332 - loss: 0.3752
# Epoch 44/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8330 - loss: 0.3733
# Epoch 45/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8332 - loss: 0.3746
# Epoch 46/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8358 - loss: 0.3723
# Epoch 47/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8363 - loss: 0.3721
# Epoch 48/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8354 - loss: 0.3709
# Epoch 49/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8360 - loss: 0.3703
# Epoch 50/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8345 - loss: 0.3703
# Epoch 51/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8365 - loss: 0.3699
# Epoch 52/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8390 - loss: 0.3693
# Epoch 53/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8335 - loss: 0.3683
# Epoch 54/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8356 - loss: 0.3661
# Epoch 55/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8373 - loss: 0.3662
# Epoch 56/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8354 - loss: 0.3672
# Epoch 57/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8312 - loss: 0.3648
# Epoch 58/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8374 - loss: 0.3645
# Epoch 59/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.
100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8678 - loss: 0.3091
# Epoch 91/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8668 - loss: 0.3084
# Epoch 92/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8652 - loss: 0.3112
# Epoch 93/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8666 - loss: 0.3103
# Epoch 94/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8701 - loss: 0.3074
# Epoch 95/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8692 - loss: 0.3078
# Epoch 96/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8680 - loss: 0.3100
# Epoch 97/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8702 - loss: 0.3074
# Epoch 98/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8658 - loss: 0.3089
# Epoch 99/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8719 - loss: 0.3075
# Epoch 100/100
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8712 - loss: 0.3055

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7859 - loss: 0.5701
# Test Loss: 0.57011878490448
# Test Accuracy: 0.7859382033348083

# %%
plt.figure(figsize=(15,10))
plt.plot(history.history['accuracy'], label='Accuracy')  # Shows how accuracy improves
plt.plot(history.history['loss'], label='Loss')          # Shows how loss decreases

plt.title('Model Training Performance')
plt.ylabel('Value')
plt.xlabel('Epoch')
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.layers import Dropout

# %%
model_drop = Sequential([
    Dense(units=10, activation='relu', input_dim=16),
    Dropout(0.2),
    Dense(units=16, activation='relu'),
    Dropout(0.16),

    Dense(units=16, activation='relu'),
    Dropout(0.12),
    Dense(units=16, activation='relu'),
    Dropout(0.08),
    Dense(units=16, activation='relu'),
    Dropout(0.04),
    Dense(units=16, activation='relu'),
    Dropout(0.02),
    Dense(units=16, activation='relu'),
    # Output layer: 1 neuron with 'softmax' activation to output a probability
    Dense(units=2, activation='softmax')])
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_drop.compile(optimizer=Adam(learning_rate=0.0005), 
loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
tf.config.run_functions_eagerly(True)
tf.compat.v1.enable_eager_execution()

# %%
history_drop=model_drop.fit(x_train, y_train, epochs=17, batch_size=10)
# Out:
# Epoch 1/17
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 144s 161ms/step - accuracy: 0.7966 - loss: 0.4547
# Epoch 2/17
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 135s 151ms/step - accuracy: 0.7998 - loss: 0.4548
# Epoch 3/17
# 893/893 ━━━━━━━━━━━━━━━━━━━━ 144s 161ms/step - accuracy: 0.7996 - loss: 0.4485
# Epoch 4/17
# 701/893 ━━━━━━━━━━━━━━━━━━━━ 30s 157ms/step - accuracy: 0.7981 - loss: 0.4438
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 history_drop=model_drop.fit(x_train, y_train, epochs=17, batch_size=10)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:810, in Function.__call__(self, *args, **kwds)
#     808 if self._run_functions_eagerly:
#     809   with trace.Trace(self._name, tf_function_call="eager"):
# --> 810     return self._python_function(*args, **kwds)
#     812 # Only count the statistics the first time, before initialization took
#     813 # place.
#     814 if self._created_variables is None:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:154, in TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator(iterator)
#     150 @tf.autograph.experimental.do_not_convert
#     151 def multi_step_on_iterator(iterator):
#     152     if self.steps_per_execution == 1:
#     153         return tf.experimental.Optional.from_value(
# --> 154             one_step_on_data(iterator.get_next())
#     155         )
#     157     # the spec is set lazily during the tracing of `tf.while_loop`
#     158     empty_outputs = tf.experimental.Optional.empty(None)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:125, in TensorFlowTrainer._autoconvert_optionals.<locals>.wrapper(data)
#     117 @functools.wraps(step_func)
#     118 def wrapper(data):
#     119     converted_data = tree.map_structure(
#     120         lambda i: (
#     121             None if isinstance(i, tf.experimental.Optional) else i
#     122         ),
#     123         data,
#     124     )
# --> 125     result = step_func(converted_data)
#     126     return result
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:810, in Function.__call__(self, *args, **kwds)
#     808 if self._run_functions_eagerly:
#     809   with trace.Trace(self._name, tf_function_call="eager"):
# --> 810     return self._python_function(*args, **kwds)
#     812 # Only count the statistics the first time, before initialization took
#     813 # place.
#     814 if self._created_variables is None:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:134, in TensorFlowTrainer._make_function.<locals>.one_step_on_data(data)
#     131 @tf.autograph.experimental.do_not_convert
#     132 def one_step_on_data(data):
#     133     """Runs a single training step on a batch of data."""
# --> 134     outputs = self.distribute_strategy.run(step_function, args=(data,))
#     135     outputs = reduce_per_replica(
#     136         outputs,
#     137         self.distribute_strategy,
#     138         reduction="auto",
#     139     )
#     140     return outputs
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:84, in TensorFlowTrainer.train_step(self, data)
#      81     gradients = tape.gradient(loss, trainable_weights)
#      83     # Update weights
# ---> 84     self.optimizer.apply_gradients(zip(gradients, trainable_weights))
#      85 else:
#      86     warnings.warn("The model does not have any trainable weights.")
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\optimizers\base_optimizer.py:462, in BaseOptimizer.apply_gradients(self, grads_and_vars)
#     460 def apply_gradients(self, grads_and_vars):
#     461     grads, trainable_variables = zip(*grads_and_vars)
# --> 462     self.apply(grads, trainable_variables)
#     463     # Return iterations for compat with tf.keras.
#     464     return self._iterations
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\optimizers\base_optimizer.py:526, in BaseOptimizer.apply(self, grads, trainable_variables)
#     523     grads = [g if g is None else g / scale for g in grads]
#     525 # Apply gradient updates.
# --> 526 self._backend_apply_gradients(grads, trainable_variables)
#     527 # Apply variable constraints after applying gradients.
#     528 for variable in trainable_variables:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\optimizers\base_optimizer.py:592, in BaseOptimizer._backend_apply_gradients(self, grads, trainable_variables)
#     589     self._apply_weight_decay(trainable_variables)
#     591     # Run update step.
# --> 592     self._backend_update_step(
#     593         grads, trainable_variables, self.learning_rate
#     594     )
#     596 if self.use_ema:
#     597     self._update_model_variables_moving_average(
#     598         self._trainable_variables
#     599     )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:120, in TFOptimizer._backend_update_step(self, grads, trainable_variables, learning_rate)
#     118 grads_and_vars = list(zip(grads, trainable_variables))
#     119 grads_and_vars = self._all_reduce_sum_gradients(grads_and_vars)
# --> 120 tf.__internal__.distribute.interim.maybe_merge_call(
#     121     self._distributed_tf_update_step,
#     122     self._distribution_strategy,
#     123     grads_and_vars,
#     124     learning_rate,
#     125 )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)     48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:134, in TFOptimizer._distributed_tf_update_step(self, distribution, grads_and_vars, learning_rate)
#     131     return self.update_step(grad, var, learning_rate)
#     133 for grad, var in grads_and_vars:
# --> 134     distribution.extended.update(
#     135         var,
#     136         apply_grad_to_update_var,
#     137         args=(grad, learning_rate),
#     138         group=False,
#     139     )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3007, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
# -> 3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2886, in StrategyExtendedV2._replica_ctx_update(self, var, fn, args, kwargs, group)
#    2883 def merge_fn(_, *merged_args, **merged_kwargs):
#    2884   return self.update(var, fn, merged_args, merged_kwargs, group=group)
# -> 2886 return replica_context.merge_call(merge_fn, args=args, kwargs=kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3478, in ReplicaContextBase.merge_call(self, merge_fn, args, kwargs)
#    3474   kwargs = {}
#    3476 merge_fn = autograph.tf_convert(
#    3477     merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 3478 return self._merge_call(merge_fn, args, kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3485, in ReplicaContextBase._merge_call(self, merge_fn, args, kwargs)
#    3482 _push_per_thread_mode(  # thread-local, so not needed with multiple threads
#    3483     _CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    3484 try:
# -> 3485   return merge_fn(self._strategy, *args, **kwargs)
#    3486 finally:
#    3487   _pop_per_thread_mode()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2884, in StrategyExtendedV2._replica_ctx_update.<locals>.merge_fn(_, *merged_args, **merged_kwargs)
#    2883 def merge_fn(_, *merged_args, **merged_kwargs):
# -> 2884   return self.update(var, fn, merged_args, merged_kwargs, group=group)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3005, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3002   fn = autograph.tf_convert(
#    3003       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3004   with self._container_strategy().scope():
# -> 3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
#    3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4075, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4072 def _update(self, var, fn, args, kwargs, group):
#    4073   # The implementations of _update() and _update_non_slot() are identical
#    4074   # except _update() passes `var` as the first argument to `fn()`.
# -> 4075   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4081, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4077 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4078   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4079   # once that value is used for something.
#    4080   with UpdateContext(colocate_with):
# -> 4081     result = fn(*args, **kwargs)
#    4082     if should_group:
#    4083       return result
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:131, in TFOptimizer._distributed_tf_update_step.<locals>.apply_grad_to_update_var(var, grad, learning_rate)
#     130 def apply_grad_to_update_var(var, grad, learning_rate):
# --> 131     return self.update_step(grad, var, learning_rate)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\optimizers\adam.py:135, in Adam.update_step(self, gradient, variable, learning_rate)
#     130     self.assign(v_hat, ops.maximum(v_hat, v))
#     131     v = v_hat
#     132 self.assign_sub(
#     133     variable,
#     134     ops.divide(
# --> 135         ops.multiply(m, alpha), ops.add(ops.sqrt(v), self.epsilon)
#     136     ),
#     137 )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\ops\numpy.py:6850, in multiply(x1, x2)
#    6847 x2_sparse = getattr(x2, "sparse", False)
#    6848 output_sparse = x1_sparse and not x2_sparse
#    6849 return KerasTensor(
# -> 6850     output_shape, dtype=output_dtype, sparse=output_sparse
#    6851 )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\sparse.py:627, in elementwise_binary_intersection.<locals>.sparse_wrapper(x1, x2)
#     621         return tf.IndexedSlices(
#     622             func(tf.gather(x1, x2.indices), x2.values),
#     623             x2.indices,
#     624             x2.dense_shape,
#     625         )
#     626 # Default case, no SparseTensor and no IndexedSlices.
# --> 627 return func(x1, x2)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\numpy.py:642, in multiply(x1, x2)
#     640 x1 = convert_to_tensor(x1, dtype)
#     641 x2 = convert_to_tensor(x2, dtype)
# --> 642 return tf.multiply(x1, x2)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\util\dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\math_ops.py:526, in multiply(x, y, name)
#     477 @tf_export("math.multiply", "multiply")
#     478 @dispatch.register_binary_elementwise_api
#     479 @dispatch.add_dispatch_support
#     480 def multiply(x, y, name=None):
#     481   """Returns an element-wise x * y.
#     482
#     483   For example:
#    (...)    523    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     524   """
# --> 526   return gen_math_ops.mul(x, y, name)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6832, in mul(x, y, name)
#    6830   pass
#    6831 try:
# -> 6832   return mul_eager_fallback(
#    6833       x, y, name=name, ctx=_ctx)
#    6834 except _core._SymbolicException:
#    6835   pass  # Add nodes to the TensorFlow graph.
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6852, in mul_eager_fallback(x, y, name, ctx)
#    6851 def mul_eager_fallback(x: Annotated[Any, TV_Mul_T], y: Annotated[Any, TV_Mul_T], name, ctx) -> Annotated[Any, TV_Mul_T]:
# -> 6852   _attr_T, _inputs_T = _execute.args_to_matching_eager([x, y], ctx, [_dtypes.bfloat16, _dtypes.half, _dtypes.float32, _dtypes.float64, _dtypes.uint8, _dtypes.int8, _dtypes.uint16, _dtypes.int16, _dtypes.int32, _dtypes.uint32, _dtypes.uint64, _dtypes.int64, _dtypes.complex64, _dtypes.complex128, ])
#    6853   (x, y) = _inputs_T
#    6854   _inputs_flat = [x, y]
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\execute.py:267, in args_to_matching_eager(***failed resolving arguments***)
#     265       dtype = tensor.dtype
#     266 else:
# --> 267   ret = [tensor_conversion_registry.convert(t, dtype) for t in l]
#     269 # TODO(slebedev): consider removing this as it leaks a Keras concept.
#     270 # pylint: disable=protected-access
#     271 keras_symbolic_tensors = [x for x in ret if _is_keras_symbolic_tensor(x)]
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\core.py:84, in Variable.__tf_tensor__(self, dtype, name)
#      83 def __tf_tensor__(self, dtype=None, name=None):
# ---> 84     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\util\dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\framework\tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)    159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\framework\tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)    230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:2378, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2377 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2378   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1624, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1622   return self.read_value().op.inputs[0]
#    1623 else:
# -> 1624   return self.value()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:658, in BaseResourceVariable.value(self)
#     656   return self._cached_value
#     657 with ops.colocate_with(None, ignore_existing=True):
# --> 658   return self._read_variable_op()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:843, in BaseResourceVariable._read_variable_op(self, no_copy)
#     841       result = read_and_set_handle(no_copy)
#     842 else:
# --> 843   result = read_and_set_handle(no_copy)
#     845 if not context.executing_eagerly():
#     846   # Note that if a control flow context is active the input of the read op
#     847   # might not actually be the handle. This line bypasses it.
#     848   record.record_operation(
#     849       "ReadVariableOp", [result], [self.handle],
#     850       backward_function=lambda x: [x],
#     851       forward_function=lambda x: [x])
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:833, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     831 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     832   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 833 result = gen_resource_variable_ops.read_variable_op(
#     834     self.handle, self._dtype)
#     835 _maybe_set_handle_data(self._dtype, self.handle, result)
#     836 return result
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:534, in read_variable_op(resource, dtype, name)
#     532 if tld.is_eager:
#     533   try:
# --> 534     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536     return _result
#     537   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
